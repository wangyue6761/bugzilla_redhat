# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup

bug_list = {}

url = "https://bugzilla.redhat.com/buglist.cgi?bug_status=VERIFIED&bug_status=CLOSED&columnlist=product%2Ccomponent%2Cassigned_to%2Cstatus%2Csummary%2Clast_change_time%2Cseverity%2Cpriority&order=priority%2C%20severity%2C%20&query_format=advanced&short_desc=CVE&short_desc_type=allwordssubstr"

browser = webdriver.Chrome()
browser.get(url)
time.sleep(10)

pageSource = browser.page_source

soup = BeautifulSoup(pageSource, 'html.parser')
bug_table = soup.find("tbody")
print(bug_table)

with open("bug.html", "w") as file:
    file.write(bug_table.prettify())

browser.close()
# Out:
# <tbody>
# <tr class="bz_CLOSED bz_unspecified bz_closed bz_public odd" id="561358"><td class="bz_id_column"><a class="bz_bug_link bz_CLOSED bz_unspecified bz_unspecified bz_closed bz_public" href="show_bug.cgi?id=561358" title="CVE-2010-0010 httpd (v1.3): mod_proxy overflow on 64-bit systems">561358</a></td><td class="bz_product_column"><span class="nowrap"> Security Response</span><a href="enter_bug.cgi?product=Security Response" title="Create a new bug for this product"> <i class="fas fa-plus-circle"></i></a></td><td class="bz_component_column"><span class="nowrap">vulnerability<a href="enter_bug.cgi?component=vulnerability&amp;product=Security Response" title="Create a new bug for this component"> <i class="fas fa-plus-circle"></i></a></span></td><td class="bz_assigned_to_column">Red Hat Product Security</td><td class="bz_status_column">CLOSED</td><td class="bz_summary_column"><a class="bz_bug_link bz_CLOSED bz_unspecified bz_unspecified bz_closed bz_public" href="show_bug.cgi?id=561358" title="CVE-2010-0010 httpd (v1.3): mod_proxy overflow on 64-bit systems">CVE-2010-0010 httpd (v1.3): mod_proxy overflow on 64-bit systems</a></td><td class="bz_last_change_time_column">2019-09-29T12:34:36Z</td><td class="bz_severity_column sorting_2">unspecified</td><td class="bz_priority_column sorting_1">unspecified</td></tr><tr class="bz_CLOSED bz_unspecified bz_closed bz_public even" id="577578"><td class="bz_id_column"><a class="bz_bug_link bz_CLOSED bz_unspecified bz_unspecified bz_closed bz_public" href="show_bug.cgi?id=577578" title="CVE-2010-1129 CVE-2010-1130 php: safe_mode / open_basedir security fixes in 5.2.13/5.3.2">577578</a></td><td class="bz_product_column"><span class="nowrap"> Security Response</span><a href="enter_bug.cgi?product=Security Response" title="Create a new bug for this product"> <i class="fas fa-plus-circle"></i></a></td><td class="bz_component_column"><span class="nowrap">vulnerability<a href="enter_bug.cgi?component=vulnerability&amp;product=Security Response" title="Create a new bug for this component"> <i class="fas fa-plus-circle"></i></a></span></td><td class="bz_assigned_to_column">Red Hat Product Security</td><td class="bz_status_column">CLOSED</td><td class="bz_summary_column"><a class="bz_bug_link bz_CLOSED bz_unspecified bz_unspecified bz_closed bz_public" href="show_bug.cgi?id=577578" title="CVE-2010-1129 CVE-2010-1130 php: safe_mode / open_basedir security fixes in 5.2.13/5.3.2">CVE-2010-1129 CVE-2010-1130 php: safe_mode / open_basedir security fixes in 5.2.13/5.3.2</a></td><td class="bz_last_change_time_column">2021-02-25T01:25:16Z</td><td class="bz_severity_column sorting_2">unspecified</td><td class="bz_priority_column sorting_1">unspecified</td></tr><tr class="bz_CLOSED bz_unspecified bz_closed bz_public odd" id="580105"><td class="bz_id_column"><a class="bz_bug_link bz_CLOSED bz_unspecified bz_unspecified bz_closed bz_public" href="show_bug.cgi?id=580105" title="CVE-2010-0206 xpdf: Invalid pointer dereference by processing JBIG2 PDF stream objects">580105</a></td><td class="bz_product_column"><span class="nowrap"> Security Response</span><a href="enter_bug.cgi?product=Security Response" title="Create a new bug for this product"> <i class="fas fa-plus-circle"></i></a></td><td class="bz_component_column"><span class="nowrap">vulnerability<a href="enter_bug.cgi?component=vulnerability&amp;product=Security Response" title="Create a new bug for this component"> <i class="fas fa-plus-circle"></i></a></span></td><td class="bz_assigned_to_column">Red Hat Product Security</td><td class="bz_status_column">CLOSED</td><td class="bz_summary_column"><a class="bz_bug_link bz_CLOSED bz_unspecified bz_unspecified bz_closed bz_public" href="show_bug.cgi?id=580105" title="CVE-2010-0206 xpdf: Invalid pointer dereference by processing JBIG2 PDF stream objects">CVE-2010-0206 xpdf: Invalid pointer dereference by processing JBIG2 PDF stream objects</a></td><td class="bz_last_change_time_column">2019-09-29T12:36:04Z</td><td c ...

# %%
import re
for bug_row in bug_table.contents:
    try:
        bug_link = bug_row.find('a', class_='bz_bug_link')
        bug_id = bug_link.get('href').split('=')[-1]
        summary_element = bug_row.find('td', class_='bz_summary_column')
        summary = summary_element.text
        cve_pattern = r'CVE-\d{4}-\d{4}'
        cveid = re.findall(cve_pattern, summary)
        print(cveid)
    except:
        pass
# Out:
# ['CVE-2010-0010']
# ['CVE-2010-1129', 'CVE-2010-1130']
# ['CVE-2010-0206']
# ['CVE-2010-0207']
# ['CVE-2010-1635', 'CVE-2010-1642']
# ['CVE-2010-2097']
# ['CVE-2009-4880']
# ['CVE-2009-4881']
# ['CVE-2010-2117']
# ['CVE-2010-2190']
# ['CVE-2010-2191']
# ['CVE-2010-1914']
# ['CVE-2010-1915']
# ['CVE-2010-1864']
# ['CVE-2010-1860']
# ['CVE-2010-1862']
# ['CVE-2010-1861']
# ['CVE-2010-2100']
# ['CVE-2010-2101']
# ['CVE-2010-2484']
